# %% [markdown]
# # Introduction to Pandas
#
# In this section of the course we will learn how to use pandas for data analysis. Think of pandas as an extremely powerful version of Excel, with a lot more features. In this section of the course, you should go through the notebooks in this order:
#
# * Introduction to Pandas
# * Series
# * DataFrames
# * Summary Functions and Aggregation (GroupBy)
# * Combining Data - Merging, Joining, and Concatenating (Optional)
# * Operations
# * Data Input and Output
# ___

# %%
# Importing required libraries and fixing options
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %matplotlib inline

# %% [markdown]
# ## Let's explore some COVID19 data available online using basic **Pandas functions**:
# [Reference](https://ourworldindata.org/coronavirus/country/indonesia)

# %%
# Importing the data from file
covid_df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')


# Let's see a sample of the data
covid_df.head() # top 5 rows
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.126                  0.126
# 1                    0.126                  0.000
# 2                    0.126                  0.000
# 3                    0.126                  0.000
# 4                    0.126                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                 NaN          NaN        NaN
# 1                                 NaN          NaN        NaN
# 2                                 NaN          NaN        NaN
# 3                                 NaN          NaN        NaN
# 4                                 NaN          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0             NaN               NaN                        NaN
# 1             NaN               NaN                        NaN
# 2             NaN               NaN                        NaN
# 3             NaN               NaN                        NaN
# 4             NaN               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  population  \
# 0                                         NaN              8.33  39835428.0
# 1                                         NaN              8.33  39835428.0
# 2                                         NaN              8.33  39835428.0
# 3                                         NaN              8.33  39835428.0
# 4                                         NaN              8.33  39835428.0
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN

# %%
covid_df.tail(10) #last 5 rows
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 176449      ZWE    Africa  Zimbabwe  2022-03-26     245645.0        0.0
# 176450      ZWE    Africa  Zimbabwe  2022-03-27     245820.0      175.0
# 176451      ZWE    Africa  Zimbabwe  2022-03-28     245927.0      107.0
# 176452      ZWE    Africa  Zimbabwe  2022-03-29     246042.0      115.0
# 176453      ZWE    Africa  Zimbabwe  2022-03-30     246182.0      140.0
# 176454      ZWE    Africa  Zimbabwe  2022-03-31     246286.0      104.0
# 176455      ZWE    Africa  Zimbabwe  2022-04-01     246414.0      128.0
# 176456      ZWE    Africa  Zimbabwe  2022-04-02     246481.0       67.0
# 176457      ZWE    Africa  Zimbabwe  2022-04-03     246525.0       44.0
# 176458      ZWE    Africa  Zimbabwe  2022-04-04     246612.0       87.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 176449             170.429        5436.0         0.0                1.429
# 176450             195.429        5438.0         2.0                1.714
# 176451             177.429        5438.0         0.0                1.286
# 176452             193.857        5439.0         1.0                1.429
# 176453             174.857        5440.0         1.0                1.143
# 176454             156.000        5444.0         4.0                1.714
# 176455             109.857        5444.0         0.0                1.143
# 176456             119.429        5446.0         2.0                1.429
# 176457             100.714        5446.0         0.0                1.143
# 176458              97.857        5451.0         5.0                1.857
#
#         total_cases_per_million  new_cases_per_million  \
# 176449                16276.320                  0.000
# 176450                16287.915                 11.595
# 176451                16295.005                  7.090
# 176452                16302.625                  7.620
# 176453                16311.901                  9.276
# 176454                16318.792                  6.891
# 176455                16327.273                  8.481
# 176456                16331.713                  4.439
# 176457                16334.628                  2.915
# 176458                16340.393                  5.765
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 176449                          11.293                   360.187
# 176450                          12.949                   360.319
# 176451                          11.756                   360.319
# 176452                          12.845                   360.386
# 176453                          11.586                   360.452
# 176454                          10.336                   360.717
# 176455                           7.279                   360.717
# 176456                           7.913                   360.849
# 176457                           6.673                   360.849
# 176458                           6.484                   361.181
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 176449                   0.000                            0.095
# 176450                   0.133                            0.114
# 176451                   0.000                            0.085
# 176452                   0.066                            0.095
# 176453                   0.066                            0.076
# 176454                   0.265                            0.114
# 176455                   0.000                            0.076
# 176456                   0.133                            0.095
# 176457                   0.000                            0.076
# 176458                   0.331                            0.123
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 176449               0.68           NaN                       NaN
# 176450               0.67           NaN                       NaN
# 176451               0.64           NaN                       NaN
# 176452               0.62           NaN                       NaN
# 176453               0.60           NaN                       NaN
# 176454               0.59           NaN                       NaN
# 176455               0.58           NaN                       NaN
# 176456                NaN           NaN                       NaN
# 176457                NaN           NaN                       NaN
# 176458                NaN           NaN                       NaN
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 176449            NaN                        NaN                    NaN
# 176450            NaN                        NaN                    NaN
# 176451            NaN                        NaN                    NaN
# 176452            NaN                        NaN                    NaN
# 176453            NaN                        NaN                    NaN
# 176454            NaN                        NaN                    NaN
# 176455            NaN                        NaN                    NaN
# 176456            NaN                        NaN                    NaN
# 176457            NaN                        NaN                    NaN
# 176458            NaN                        NaN                    NaN
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 176449                                NaN                     NaN
# 176450                                NaN                     NaN
# 176451                                NaN                     NaN
# 176452                                NaN                     NaN
# 176453                                NaN                     NaN
# 176454                                NaN                     NaN
# 176455                                NaN                     NaN
# 176456                                NaN                     NaN
# 176457                                NaN                     NaN
# 176458                                NaN                     NaN
#
#         weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 176449                                 NaN          NaN        NaN
# 176450                                 NaN          NaN        NaN
# 176451                                 NaN    2176708.0        NaN
# 176452                                 NaN          NaN        NaN
# 176453                                 NaN          NaN        NaN
# 176454                                 NaN          NaN        NaN
# 176455                                 NaN    2185767.0        NaN
# 176456                                 NaN          NaN        NaN
# 176457                                 NaN          NaN        NaN
# 176458                                 NaN          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 176449                       NaN                     NaN              2682.0
# 176450                       NaN                     NaN              2648.0
# 176451                   144.228                     NaN              2747.0
# 176452                       NaN                     NaN              2735.0
# 176453                       NaN                     NaN              2723.0
# 176454                       NaN                     NaN              2711.0
# 176455                   144.828                     NaN              2599.0
# 176456                       NaN                     NaN                 NaN
# 176457                       NaN                     NaN                 NaN
# 176458                       NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 176449                            0.178         0.0635            15.7
# 176450                            0.175         0.0738            13.5
# 176451                            0.182         0.0646            15.5
# 176452                            0.181         0.0709            14.1
# 176453                            0.180         0.0642            15.6
# 176454                            0.180         0.0575            17.4
# 176455                            0.172         0.0423            23.7
# 176456                              NaN            NaN             NaN
# 176457                              NaN            NaN             NaN
# 176458                              NaN            NaN             NaN
#
#             tests_units  total_vaccinations  people_vaccinated  \
# 176449  tests performed           8791728.0          4886242.0
# 176450  tests performed           8845039.0          4918147.0
# 176451  tests performed           8934360.0          4975433.0
# 176452  tests performed           9039729.0          5053114.0
# 176453  tests performed           9202369.0          5175175.0
# 176454  tests performed           9368822.0          5297081.0
# 176455  tests performed           9481194.0          5372837.0
# 176456              NaN           9600524.0          5455680.0
# 176457              NaN           9694465.0          5517779.0
# 176458              NaN                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  new_vaccinations  \
# 176449                3487962.0        417524.0          100086.0
# 176450                3493763.0        433129.0           53311.0
# 176451                3501493.0        457434.0           89321.0
# 176452                3510256.0        476359.0          105369.0
# 176453                3522062.0        505132.0          162640.0
# 176454                3532708.0        539033.0          166453.0
# 176455                3543725.0        564632.0          112372.0
# 176456                3553083.0        591761.0          119330.0
# 176457                3561400.0        615286.0           93941.0
# 176458                      NaN             NaN               NaN
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 176449                    83429.0                           58.25
# 176450                    90629.0                           58.61
# 176451                   100614.0                           59.20
# 176452                   103751.0                           59.90
# 176453                   112556.0                           60.97
# 176454                   116628.0                           62.08
# 176455                   112793.0                           62.82
# 176456                   115542.0                           63.61
# 176457                   121347.0                           64.24
# 176458                        NaN                             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 176449                          32.38                                23.11
# 176450                          32.59                                23.15
# 176451                          32.97                                23.20
# 176452                          33.48                                23.26
# 176453                          34.29                                23.34
# 176454                          35.10                                23.41
# 176455                          35.60                                23.48
# 176456                          36.15                                23.54
# 176457                          36.56                                23.60
# 176458                            NaN                                  NaN
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 176449                        2.77                                 5528.0
# 176450                        2.87                                 6005.0
# 176451                        3.03                                 6667.0
# 176452                        3.16                                 6874.0
# 176453                        3.35                                 7458.0
# 176454                        3.57                                 7728.0
# 176455                        3.74                                 7474.0
# 176456                        3.92                                 7656.0
# 176457                        4.08                                 8040.0
# 176458                         NaN                                    NaN
#
#         new_people_vaccinated_smoothed  \
# 176449                         66887.0
# 176450                         71313.0
# 176451                         77545.0
# 176452                         78454.0
# 176453                         83638.0
# 176454                         84623.0
# 176455                         79751.0
# 176456                         81348.0
# 176457                         85662.0
# 176458                             NaN
#
#         new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 176449                                       0.443               NaN
# 176450                                       0.473               NaN
# 176451                                       0.514               NaN
# 176452                                       0.520               NaN
# 176453                                       0.554               NaN
# 176454                                       0.561               NaN
# 176455                                       0.528               NaN
# 176456                                       0.539               NaN
# 176457                                       0.568               NaN
# 176458                                         NaN               NaN
#
#         population  population_density  median_age  aged_65_older  \
# 176449  15092171.0              42.729        19.6          2.822
# 176450  15092171.0              42.729        19.6          2.822
# 176451  15092171.0              42.729        19.6          2.822
# 176452  15092171.0              42.729        19.6          2.822
# 176453  15092171.0              42.729        19.6          2.822
# 176454  15092171.0              42.729        19.6          2.822
# 176455  15092171.0              42.729        19.6          2.822
# 176456  15092171.0              42.729        19.6          2.822
# 176457  15092171.0              42.729        19.6          2.822
# 176458  15092171.0              42.729        19.6          2.822
#
#         aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 176449          1.882        1899.775             21.4                307.846
# 176450          1.882        1899.775             21.4                307.846
# 176451          1.882        1899.775             21.4                307.846
# 176452          1.882        1899.775             21.4                307.846
# 176453          1.882        1899.775             21.4                307.846
# 176454          1.882        1899.775             21.4                307.846
# 176455          1.882        1899.775             21.4                307.846
# 176456          1.882        1899.775             21.4                307.846
# 176457          1.882        1899.775             21.4                307.846
# 176458          1.882        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 176449                 1.82             1.6          30.7
# 176450                 1.82             1.6          30.7
# 176451                 1.82             1.6          30.7
# 176452                 1.82             1.6          30.7
# 176453                 1.82             1.6          30.7
# 176454                 1.82             1.6          30.7
# 176455                 1.82             1.6          30.7
# 176456                 1.82             1.6          30.7
# 176457                 1.82             1.6          30.7
# 176458                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 176449                  36.791                         1.7            61.49
# 176450                  36.791                         1.7            61.49
# 176451                  36.791                         1.7            61.49
# 176452                  36.791                         1.7            61.49
# 176453                  36.791                         1.7            61.49
# 176454                  36.791                         1.7            61.49
# 176455                  36.791                         1.7            61.49
# 176456                  36.791                         1.7            61.49
# 176457                  36.791                         1.7            61.49
# 176458                  36.791                         1.7            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 176449                    0.571                                   NaN
# 176450                    0.571                                   NaN
# 176451                    0.571                                   NaN
# 176452                    0.571                                   NaN
# 176453                    0.571                                   NaN
# 176454                    0.571                                   NaN
# 176455                    0.571                                   NaN
# 176456                    0.571                                   NaN
# 176457                    0.571                                   NaN
# 176458                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 176449                          NaN               NaN
# 176450                          NaN               NaN
# 176451                          NaN               NaN
# 176452                          NaN               NaN
# 176453                          NaN               NaN
# 176454                          NaN               NaN
# 176455                          NaN               NaN
# 176456                          NaN               NaN
# 176457                          NaN               NaN
# 176458                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 176449                                      NaN
# 176450                                      NaN
# 176451                                      NaN
# 176452                                      NaN
# 176453                                      NaN
# 176454                                      NaN
# 176455                                      NaN
# 176456                                      NaN
# 176457                                      NaN
# 176458                                      NaN

# %%
covid_df.sample(10,random_state = 111) #Sample 10 rows randomly selected from the data
# Out:
#        iso_code      continent                      location        date  \
# 171732      VEN  South America                     Venezuela  2021-04-02
# 167084      VIR  North America  United States Virgin Islands  2020-05-16
# 156261      TZA         Africa                      Tanzania  2020-05-07
# 65348       GTM  North America                     Guatemala  2020-07-06
# 19651       BOL  South America                       Bolivia  2021-06-16
# 66282       GGY         Europe                      Guernsey  2021-11-16
# 109401      MOZ         Africa                    Mozambique  2021-10-25
# 35593       COG         Africa                         Congo  2021-08-03
# 121947      PAK           Asia                      Pakistan  2020-05-29
# 81922       JEY         Europe                        Jersey  2021-06-12
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 171732     162730.0      979.0            1117.857        1629.0        14.0
# 167084          NaN        NaN                 NaN           NaN         NaN
# 156261        480.0        0.0               0.000          16.0         0.0
# 65348       23972.0      724.0             937.571         981.0        34.0
# 19651      414513.0     2836.0            3076.857       15826.0        88.0
# 66282           NaN        NaN                 NaN           NaN         NaN
# 109401     151226.0        1.0              16.286        1928.0         0.0
# 35593       13216.0        0.0               8.571         178.0         0.0
# 121947      66457.0     2429.0            2002.857        1395.0        78.0
# 81922           NaN        NaN                 NaN           NaN         NaN
#
#         new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 171732               12.286                 5669.058                 34.106
# 167084                  NaN                      NaN                    NaN
# 156261                0.000                    7.805                  0.000
# 65348                33.571                 1313.544                 39.672
# 19651                92.714                35030.444                239.670
# 66282                   NaN                      NaN                    NaN
# 109401                0.143                 4701.856                  0.031
# 35593                 0.143                 2336.214                  0.000
# 121947               42.000                  295.102                 10.786
# 81922                   NaN                      NaN                    NaN
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 171732                          38.943                    56.750
# 167084                             NaN                       NaN
# 156261                           0.000                     0.260
# 65348                           51.374                    53.754
# 19651                          260.025                  1337.453
# 66282                              NaN                       NaN
# 109401                           0.506                    59.945
# 35593                            1.515                    31.465
# 121947                           8.894                     6.194
# 81922                              NaN                       NaN
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 171732                   0.488                            0.428
# 167084                     NaN                              NaN
# 156261                   0.000                            0.000
# 65348                    1.863                            1.840
# 19651                    7.437                            7.835
# 66282                      NaN                              NaN
# 109401                   0.000                            0.004
# 35593                    0.000                            0.025
# 121947                   0.346                            0.187
# 81922                      NaN                              NaN
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 171732               1.19           NaN                       NaN
# 167084                NaN           NaN                       NaN
# 156261               0.21           NaN                       NaN
# 65348                1.23           NaN                       NaN
# 19651                0.96         220.0                    18.592
# 66282                 NaN           NaN                       NaN
# 109401               0.70           NaN                       NaN
# 35593                0.66           NaN                       NaN
# 121947               1.34           NaN                       NaN
# 81922                 NaN           NaN                       NaN
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 171732            NaN                        NaN                    NaN
# 167084            NaN                        NaN                    NaN
# 156261            NaN                        NaN                    NaN
# 65348             NaN                        NaN                    NaN
# 19651          2170.0                    183.386                    NaN
# 66282             NaN                        NaN                    NaN
# 109401            NaN                        NaN                    NaN
# 35593             NaN                        NaN                    NaN
# 121947            NaN                        NaN                    NaN
# 81922             NaN                        NaN                    NaN
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 171732                                NaN                     NaN
# 167084                                NaN                     NaN
# 156261                                NaN                     NaN
# 65348                                 NaN                     NaN
# 19651                                 NaN                     NaN
# 66282                                 NaN                     NaN
# 109401                                NaN                     NaN
# 35593                                 NaN                     NaN
# 121947                                NaN                     NaN
# 81922                                 NaN                     NaN
#
#         weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 171732                                 NaN          NaN        NaN
# 167084                                 NaN        427.0        1.0
# 156261                                 NaN          NaN        NaN
# 65348                                  NaN      77626.0     2960.0
# 19651                                  NaN    1684774.0    16131.0
# 66282                                  NaN          NaN        NaN
# 109401                                 NaN          NaN        NaN
# 35593                                  NaN          NaN        NaN
# 121947                                 NaN     520017.0    11931.0
# 81922                                  NaN          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 171732                       NaN                     NaN                 NaN
# 167084                     4.097                   0.010                10.0
# 156261                       NaN                     NaN                 NaN
# 65348                      4.254                   0.162              2969.0
# 19651                    142.380                   1.363             12821.0
# 66282                        NaN                     NaN                 NaN
# 109401                       NaN                     NaN              1160.0
# 35593                        NaN                     NaN                 NaN
# 121947                     2.309                   0.053             10576.0
# 81922                        NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 171732                              NaN            NaN             NaN
# 167084                            0.096         0.0000             NaN
# 156261                              NaN            NaN             NaN
# 65348                             0.163         0.3158             3.2
# 19651                             1.084         0.2400             4.2
# 66282                               NaN            NaN             NaN
# 109401                            0.036         0.0140            71.2
# 35593                               NaN            NaN             NaN
# 121947                            0.047         0.1894             5.3
# 81922                               NaN            NaN             NaN
#
#             tests_units  total_vaccinations  people_vaccinated  \
# 171732              NaN             98000.0            98000.0
# 167084  tests performed                 NaN                NaN
# 156261              NaN                 NaN                NaN
# 65348     people tested                 NaN                NaN
# 19651   tests performed           2151088.0          1594489.0
# 66282               NaN                 NaN                NaN
# 109401  tests performed                 NaN                NaN
# 35593               NaN                 NaN                NaN
# 121947  tests performed                 NaN                NaN
# 81922               NaN                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  new_vaccinations  \
# 171732                      NaN             NaN               NaN
# 167084                      NaN             NaN               NaN
# 156261                      NaN             NaN               NaN
# 65348                       NaN             NaN               NaN
# 19651                  556599.0             NaN           33866.0
# 66282                       NaN             NaN               NaN
# 109401                      NaN             NaN               NaN
# 35593                       NaN             NaN               NaN
# 121947                      NaN             NaN               NaN
# 81922                       NaN             NaN               NaN
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 171732                    11968.0                            0.34
# 167084                        NaN                             NaN
# 156261                        NaN                             NaN
# 65348                         NaN                             NaN
# 19651                     23955.0                           18.18
# 66282                        25.0                             NaN
# 109401                    81395.0                             NaN
# 35593                      3636.0                             NaN
# 121947                        NaN                             NaN
# 81922                       496.0                             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 171732                           0.34                                  NaN
# 167084                            NaN                                  NaN
# 156261                            NaN                                  NaN
# 65348                             NaN                                  NaN
# 19651                           13.48                                  4.7
# 66282                             NaN                                  NaN
# 109401                            NaN                                  NaN
# 35593                             NaN                                  NaN
# 121947                            NaN                                  NaN
# 81922                             NaN                                  NaN
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 171732                         NaN                                  417.0
# 167084                         NaN                                    NaN
# 156261                         NaN                                    NaN
# 65348                          NaN                                    NaN
# 19651                          NaN                                 2024.0
# 66282                          NaN                                  394.0
# 109401                         NaN                                 2531.0
# 35593                          NaN                                  643.0
# 121947                         NaN                                    NaN
# 81922                          NaN                                 4907.0
#
#         new_people_vaccinated_smoothed  \
# 171732                         11968.0
# 167084                             NaN
# 156261                             NaN
# 65348                              NaN
# 19651                          12645.0
# 66282                             80.0
# 109401                         62122.0
# 35593                           1606.0
# 121947                             NaN
# 81922                            310.0
#
#         new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 171732                                       0.042             87.96
# 167084                                         NaN             39.81
# 156261                                         NaN             52.78
# 65348                                          NaN             96.30
# 19651                                        0.107             27.78
# 66282                                        0.126               NaN
# 109401                                       0.193             48.15
# 35593                                        0.028             48.15
# 121947                                         NaN             82.41
# 81922                                        0.307               NaN
#
#          population  population_density  median_age  aged_65_older  \
# 171732   28704947.0              36.253        29.0          6.614
# 167084     104218.0             306.480        42.2         18.601
# 156261   61498438.0              64.699        17.7          3.108
# 65348    18249868.0             157.834        22.9          4.694
# 19651    11832936.0              10.202        25.4          6.704
# 66282       63385.0                 NaN         NaN            NaN
# 109401   32163045.0              37.728        17.7          3.158
# 35593     5657017.0              15.405        19.0          3.402
# 121947  225199929.0             255.573        23.5          4.495
# 81922      101073.0                 NaN         NaN            NaN
#
#         aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 171732          3.915       16745.022              NaN                204.850
# 167084         10.799             NaN              NaN                273.670
# 156261          1.874        2683.304             49.1                217.288
# 65348           3.016        7423.808              8.7                155.898
# 19651           4.393        6885.829              7.1                204.299
# 66282             NaN             NaN              NaN                    NaN
# 109401          1.870        1136.103             62.9                329.942
# 35593           2.063        4881.406             37.0                344.094
# 121947          2.780        5034.708              4.0                423.031
# 81922             NaN             NaN              NaN                    NaN
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 171732                 6.47             NaN           NaN
# 167084                12.26             NaN           NaN
# 156261                 5.75             3.3          26.7
# 65348                 10.18             NaN           NaN
# 19651                  6.89             NaN           NaN
# 66282                   NaN             NaN           NaN
# 109401                 3.30             5.1          29.1
# 35593                  7.20             1.7          52.3
# 121947                 8.35             2.8          36.7
# 81922                   NaN             NaN           NaN
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 171732                     NaN                         0.8            72.06
# 167084                     NaN                         NaN            80.58
# 156261                  47.953                         0.7            65.46
# 65348                   76.665                         0.6            74.30
# 19651                   25.383                         1.1            71.51
# 66282                      NaN                         NaN              NaN
# 109401                  12.227                         0.7            60.85
# 35593                   47.964                         NaN            64.57
# 121947                  59.607                         0.6            67.27
# 81922                      NaN                         NaN              NaN
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 171732                    0.711                                   NaN
# 167084                      NaN                                   NaN
# 156261                    0.529                                   NaN
# 65348                     0.663                                   NaN
# 19651                     0.718                                   NaN
# 66282                       NaN                                   NaN
# 109401                    0.456                                   NaN
# 35593                     0.574                                   NaN
# 121947                    0.557                                   NaN
# 81922                       NaN                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 171732                          NaN               NaN
# 167084                          NaN               NaN
# 156261                          NaN               NaN
# 65348                           NaN               NaN
# 19651                           NaN               NaN
# 66282                           NaN               NaN
# 109401                          NaN               NaN
# 35593                           NaN               NaN
# 121947                          NaN               NaN
# 81922                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 171732                                      NaN
# 167084                                      NaN
# 156261                                      NaN
# 65348                                       NaN
# 19651                                       NaN
# 66282                                       NaN
# 109401                                      NaN
# 35593                                       NaN
# 121947                                      NaN
# 81922                                       NaN

# %%
covid_df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus',
#        'Northern Mariana Islands', 'Norway', 'Oceania', 'Oman',
#        'Pakistan', 'Palau', 'Palestine', 'Panama', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna', 'World',
#        'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
covid_df.shape
# Out:
# (176459, 67)

# %%
interested_countries_list = ['India','Indonesia']
covid_df1 = covid_df[covid_df['location'].isin(interested_countries_list)]

# %%
covid_df1.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 73296      IND      Asia    India  2020-01-30          1.0        1.0
# 73297      IND      Asia    India  2020-01-31          1.0        0.0
# 73298      IND      Asia    India  2020-02-01          1.0        0.0
# 73299      IND      Asia    India  2020-02-02          2.0        1.0
# 73300      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 73296                 NaN           NaN         NaN                  NaN
# 73297                 NaN           NaN         NaN                  NaN
# 73298                 NaN           NaN         NaN                  NaN
# 73299                 NaN           NaN         NaN                  NaN
# 73300                 NaN           NaN         NaN                  NaN
#
#        total_cases_per_million  new_cases_per_million  \
# 73296                    0.001                  0.001
# 73297                    0.001                  0.000
# 73298                    0.001                  0.000
# 73299                    0.001                  0.001
# 73300                    0.002                  0.001
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 73296                             NaN                       NaN
# 73297                             NaN                       NaN
# 73298                             NaN                       NaN
# 73299                             NaN                       NaN
# 73300                             NaN                       NaN
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  \
# 73296                     NaN                              NaN
# 73297                     NaN                              NaN
# 73298                     NaN                              NaN
# 73299                     NaN                              NaN
# 73300                     NaN                              NaN
#
#        reproduction_rate  icu_patients  icu_patients_per_million  \
# 73296                NaN           NaN                       NaN
# 73297                NaN           NaN                       NaN
# 73298                NaN           NaN                       NaN
# 73299                NaN           NaN                       NaN
# 73300                NaN           NaN                       NaN
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 73296            NaN                        NaN                    NaN
# 73297            NaN                        NaN                    NaN
# 73298            NaN                        NaN                    NaN
# 73299            NaN                        NaN                    NaN
# 73300            NaN                        NaN                    NaN
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 73296                                NaN                     NaN
# 73297                                NaN                     NaN
# 73298                                NaN                     NaN
# 73299                                NaN                     NaN
# 73300                                NaN                     NaN
#
#        weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 73296                                 NaN          NaN        NaN
# 73297                                 NaN          NaN        NaN
# 73298                                 NaN          NaN        NaN
# 73299                                 NaN          NaN        NaN
# 73300                                 NaN          NaN        NaN
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 73296                       NaN                     NaN                 NaN
# 73297                       NaN                     NaN                 NaN
# 73298                       NaN                     NaN                 NaN
# 73299                       NaN                     NaN                 NaN
# 73300                       NaN                     NaN                 NaN
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 73296                              NaN            NaN             NaN
# 73297                              NaN            NaN             NaN
# 73298                              NaN            NaN             NaN
# 73299                              NaN            NaN             NaN
# 73300                              NaN            NaN             NaN
#
#       tests_units  total_vaccinations  people_vaccinated  \
# 73296         NaN                 NaN                NaN
# 73297         NaN                 NaN                NaN
# 73298         NaN                 NaN                NaN
# 73299         NaN                 NaN                NaN
# 73300         NaN                 NaN                NaN
#
#        people_fully_vaccinated  total_boosters  new_vaccinations  \
# 73296                      NaN             NaN               NaN
# 73297                      NaN             NaN               NaN
# 73298                      NaN             NaN               NaN
# 73299                      NaN             NaN               NaN
# 73300                      NaN             NaN               NaN
#
#        new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 73296                        NaN                             NaN
# 73297                        NaN                             NaN
# 73298                        NaN                             NaN
# 73299                        NaN                             NaN
# 73300                        NaN                             NaN
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 73296                            NaN                                  NaN
# 73297                            NaN                                  NaN
# 73298                            NaN                                  NaN
# 73299                            NaN                                  NaN
# 73300                            NaN                                  NaN
#
#        total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 73296                         NaN                                    NaN
# 73297                         NaN                                    NaN
# 73298                         NaN                                    NaN
# 73299                         NaN                                    NaN
# 73300                         NaN                                    NaN
#
#        new_people_vaccinated_smoothed  \
# 73296                             NaN
# 73297                             NaN
# 73298                             NaN
# 73299                             NaN
# 73300                             NaN
#
#        new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 73296                                         NaN             10.19
# 73297                                         NaN             10.19
# 73298                                         NaN             10.19
# 73299                                         NaN             10.19
# 73300                                         NaN             10.19
#
#          population  population_density  median_age  aged_65_older  \
# 73296  1.393409e+09             450.419        28.2          5.989
# 73297  1.393409e+09             450.419        28.2          5.989
# 73298  1.393409e+09             450.419        28.2          5.989
# 73299  1.393409e+09             450.419        28.2          5.989
# 73300  1.393409e+09             450.419        28.2          5.989
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 73296          3.414        6426.674             21.2                 282.28
# 73297          3.414        6426.674             21.2                 282.28
# 73298          3.414        6426.674             21.2                 282.28
# 73299          3.414        6426.674             21.2                 282.28
# 73300          3.414        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 73296                10.39             1.9          20.6
# 73297                10.39             1.9          20.6
# 73298                10.39             1.9          20.6
# 73299                10.39             1.9          20.6
# 73300                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 73296                   59.55                        0.53            69.66
# 73297                   59.55                        0.53            69.66
# 73298                   59.55                        0.53            69.66
# 73299                   59.55                        0.53            69.66
# 73300                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 73296                    0.645                                   NaN
# 73297                    0.645                                   NaN
# 73298                    0.645                                   NaN
# 73299                    0.645                                   NaN
# 73300                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# 73296                          NaN               NaN
# 73297                          NaN               NaN
# 73298                          NaN               NaN
# 73299                          NaN               NaN
# 73300                          NaN               NaN
#
#        excess_mortality_cumulative_per_million
# 73296                                      NaN
# 73297                                      NaN
# 73298                                      NaN
# 73299                                      NaN
# 73300                                      NaN

# %%
covid_df[covid_df['location'] == 'Indonesia'].sample(5)
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 74769      IDN      Asia  Indonesia  2022-01-08    4265666.0      479.0
# 74514      IDN      Asia  Indonesia  2021-04-28    1657035.0     5241.0
# 74586      IDN      Asia  Indonesia  2021-07-09    2455912.0    38124.0
# 74458      IDN      Asia  Indonesia  2021-03-03    1353834.0     6808.0
# 74819      IDN      Asia  Indonesia  2022-02-27    5539394.0    34976.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 74769             381.714      144127.0         6.0                4.429
# 74514            5209.429       45116.0       177.0              158.429
# 74586           32424.857       64631.0       871.0              728.143
# 74458            6813.286       36721.0       203.0              209.571
# 74819           48841.286      148073.0       229.0              244.000
#
#        total_cases_per_million  new_cases_per_million  \
# 74769                15435.079                  1.733
# 74514                 5995.890                 18.964
# 74586                 8886.583                137.950
# 74458                 4898.774                 24.634
# 74819                20043.994                126.559
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 74769                           1.381                   521.516
# 74514                          18.850                   163.250
# 74586                         117.328                   233.864
# 74458                          24.654                   132.873
# 74819                         176.730                   535.794
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  \
# 74769                   0.022                            0.016
# 74514                   0.640                            0.573
# 74586                   3.152                            2.635
# 74458                   0.735                            0.758
# 74819                   0.829                            0.883
#
#        reproduction_rate  icu_patients  icu_patients_per_million  \
# 74769               1.62           NaN                       NaN
# 74514               0.98           NaN                       NaN
# 74586               1.34           NaN                       NaN
# 74458               0.85           NaN                       NaN
# 74819               0.84           NaN                       NaN
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 74769            NaN                        NaN                    NaN
# 74514            NaN                        NaN                    NaN
# 74586            NaN                        NaN                    NaN
# 74458            NaN                        NaN                    NaN
# 74819            NaN                        NaN                    NaN
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 74769                                NaN                     NaN
# 74514                                NaN                     NaN
# 74586                                NaN                     NaN
# 74458                                NaN                     NaN
# 74819                                NaN                     NaN
#
#        weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 74769                                 NaN   44000762.0   177701.0
# 74514                                 NaN    9714274.0    41057.0
# 74586                                 NaN   14373845.0   142005.0
# 74458                                 NaN          NaN        NaN
# 74819                                 NaN   56109746.0   194731.0
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 74769                   159.214                   0.643            198058.0
# 74514                    35.151                   0.149             43121.0
# 74586                    52.011                   0.514            120905.0
# 74458                       NaN                     NaN                 NaN
# 74819                   203.030                   0.705            275833.0
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 74769                            0.717         0.0019           518.9
# 74514                            0.156         0.1208             8.3
# 74586                            0.437         0.2682             3.7
# 74458                              NaN            NaN             NaN
# 74819                            0.998         0.1771             5.6
#
#          tests_units  total_vaccinations  people_vaccinated  \
# 74769  people tested                 NaN        169580225.0
# 74514  people tested          19487346.0         12112888.0
# 74586  people tested          50644144.0         35775567.0
# 74458            NaN           3386351.0          2286123.0
# 74819  people tested         344263603.0        190672557.0
#
#        people_fully_vaccinated  total_boosters  new_vaccinations  \
# 74769              116569908.0             NaN               NaN
# 74514                7374458.0             NaN          327544.0
# 74586               14868577.0             NaN         1160956.0
# 74458                1100228.0             NaN          363003.0
# 74819              143778623.0       9812596.0            2639.0
#
#        new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 74769                  1314110.0                             NaN
# 74514                   270876.0                            7.05
# 74586                   854602.0                           18.33
# 74458                   171080.0                            1.23
# 74819                   807918.0                          124.57
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 74769                          61.36                                42.18
# 74514                           4.38                                 2.67
# 74586                          12.95                                 5.38
# 74458                           0.83                                 0.40
# 74819                          68.99                                52.03
#
#        total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 74769                         NaN                                 4755.0
# 74514                         NaN                                  980.0
# 74586                         NaN                                 3092.0
# 74458                         NaN                                  619.0
# 74819                        3.55                                 2923.0
#
#        new_people_vaccinated_smoothed  \
# 74769                       1102715.0
# 74514                        120525.0
# 74586                        697678.0
# 74458                        131855.0
# 74819                        146520.0
#
#        new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 74769                                       0.399             66.20
# 74514                                       0.044             71.76
# 74586                                       0.252             71.76
# 74458                                       0.048             71.76
# 74819                                       0.053             66.20
#
#         population  population_density  median_age  aged_65_older  \
# 74769  276361788.0             145.725        29.3          5.319
# 74514  276361788.0             145.725        29.3          5.319
# 74586  276361788.0             145.725        29.3          5.319
# 74458  276361788.0             145.725        29.3          5.319
# 74819  276361788.0             145.725        29.3          5.319
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 74769          3.053       11188.744              5.7                342.864
# 74514          3.053       11188.744              5.7                342.864
# 74586          3.053       11188.744              5.7                342.864
# 74458          3.053       11188.744              5.7                342.864
# 74819          3.053       11188.744              5.7                342.864
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 74769                 6.32             2.8          76.1
# 74514                 6.32             2.8          76.1
# 74586                 6.32             2.8          76.1
# 74458                 6.32             2.8          76.1
# 74819                 6.32             2.8          76.1
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 74769                  64.204                        1.04            71.72
# 74514                  64.204                        1.04            71.72
# 74586                  64.204                        1.04            71.72
# 74458                  64.204                        1.04            71.72
# 74819                  64.204                        1.04            71.72
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 74769                    0.718                                   NaN
# 74514                    0.718                                   NaN
# 74586                    0.718                                   NaN
# 74458                    0.718                                   NaN
# 74819                    0.718                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# 74769                          NaN               NaN
# 74514                          NaN               NaN
# 74586                          NaN               NaN
# 74458                          NaN               NaN
# 74819                          NaN               NaN
#
#        excess_mortality_cumulative_per_million
# 74769                                      NaN
# 74514                                      NaN
# 74586                                      NaN
# 74458                                      NaN
# 74819                                      NaN

# %%
# df.to_csv('covid_data_output.csv',header=True,index=False)

# %%
covid_df1.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  1.560000e+03    1557.000000         1545.000000    1510.000000
# mean   1.005796e+07   31500.055877        31735.146276  154087.947682
# std    1.347722e+07   63101.003911        62785.150417  166918.914116
# min    1.000000e+00       0.000000            0.000000       1.000000
# 25%    4.208920e+05    1922.000000         2056.429000   17238.000000
# 50%    4.168800e+06    8692.000000         8808.429000  120011.500000
# 75%    1.129138e+07   34976.000000        36257.286000  160372.250000
# max    4.302984e+07  414188.000000       391232.000000  521416.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  1505.000000          1481.000000              1560.000000
# mean    444.655814           439.899494             10054.749554
# std     718.661779           680.321236              9553.526388
# min       0.000000             0.286000                 0.001000
# 25%      81.000000            93.429000              1028.472750
# 50%     191.000000           203.429000              6933.149000
# 75%     488.000000           500.000000             16120.630500
# max    4529.000000          4190.000000             30880.982000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count            1557.000000                     1545.000000
# mean               33.814158                       34.047903
# std                51.716888                       51.112195
# min                 0.000000                        0.000000
# 25%                 4.816000                        5.247000
# 50%                15.982000                       16.090000
# 75%                34.882000                       34.071000
# max               297.248000                      280.773000
#
#        total_deaths_per_million  new_deaths_per_million  \
# count               1510.000000             1505.000000
# mean                 200.236361                0.618190
# std                  179.151502                0.988459
# min                    0.001000                0.000000
# 25%                   41.902500                0.129000
# 50%                  128.408000                0.329000
# 75%                  335.735500                0.642000
# max                  561.452000                7.487000
#
#        new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# count                      1481.000000        1495.000000           0.0
# mean                          0.618951           1.062970           NaN
# std                           0.966989           0.358635           NaN
# min                           0.000000           0.340000           NaN
# 25%                           0.148000           0.870000           NaN
# 50%                           0.351000           1.010000           NaN
# 75%                           0.642000           1.185000           NaN
# max                           6.474000           2.770000           NaN
#
#        icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# count                       0.0            0.0                        0.0
# mean                        NaN            NaN                        NaN
# std                         NaN            NaN                        NaN
# min                         NaN            NaN                        NaN
# 25%                         NaN            NaN                        NaN
# 50%                         NaN            NaN                        NaN
# 75%                         NaN            NaN                        NaN
# max                         NaN            NaN                        NaN
#
#        weekly_icu_admissions  weekly_icu_admissions_per_million  \
# count                    0.0                                0.0
# mean                     NaN                                NaN
# std                      NaN                                NaN
# min                      NaN                                NaN
# 25%                      NaN                                NaN
# 50%                      NaN                                NaN
# 75%                      NaN                                NaN
# max                      NaN                                NaN
#
#        weekly_hosp_admissions  weekly_hosp_admissions_per_million  \
# count                     0.0                                 0.0
# mean                      NaN                                 NaN
# std                       NaN                                 NaN
# min                       NaN                                 NaN
# 25%                       NaN                                 NaN
# 50%                       NaN                                 NaN
# 75%                       NaN                                 NaN
# max                       NaN                                 NaN
#
#         total_tests     new_tests  total_tests_per_thousand  \
# count  1.105000e+03  1.090000e+03               1105.000000
# mean   2.197824e+08  7.564105e+05                184.339564
# std    2.546594e+08  6.666669e+05                168.840848
# min    6.500000e+03  1.570000e+02                  0.005000
# 25%    1.903174e+07  1.490562e+05                 45.126000
# 50%    6.532578e+07  7.095925e+05                131.684000
# 75%    4.081393e+08  1.187759e+06                292.907000
# max    7.910797e+08  3.740296e+06                567.730000
#
#        new_tests_per_thousand  new_tests_smoothed  \
# count             1090.000000        1.111000e+03
# mean                 0.679972        7.569050e+05
# std                  0.409071        6.542644e+05
# min                  0.000000        1.121000e+03
# 25%                  0.403500        1.561730e+05
# 50%                  0.661000        7.047220e+05
# 75%                  0.903500        1.177798e+06
# max                  2.684000        3.080396e+06
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# count                      1111.000000    1110.000000     1110.000000
# mean                          0.677079       0.067118       85.741171
# std                           0.397558       0.067414      180.152842
# min                           0.001000       0.000900        3.300000
# 25%                           0.417500       0.017350        9.700000
# 50%                           0.671000       0.041300       24.200000
# 75%                           0.872500       0.103000       57.625000
# max                           2.211000       0.305400     1125.700000
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.140000e+02       8.610000e+02             8.260000e+02
# mean         4.633467e+08       2.855780e+08             1.743080e+08
# std          5.703292e+08       3.255458e+08             2.371021e+08
# min          0.000000e+00       0.000000e+00             5.468000e+03
# 25%          3.703499e+07       3.206374e+07             1.393694e+07
# 50%          2.018911e+08       1.437940e+08             7.483027e+07
# 75%          7.311004e+08       4.930772e+08             1.662324e+08
# max          1.847001e+09       9.910373e+08             8.337032e+08
#
#        total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# count    1.260000e+02      7.840000e+02               8.910000e+02
# mean     1.460947e+07      2.665597e+06               2.494069e+06
# std      5.509748e+06      2.926498e+06               2.436066e+06
# min      3.294338e+06      2.639000e+03               1.182300e+04
# 25%      9.608996e+06      5.480352e+05               7.112490e+05
# 50%      1.569753e+07      1.572604e+06               1.398280e+06
# 75%      1.947960e+07      3.710691e+06               4.060418e+06
# max      2.404634e+07      1.862727e+07               1.003800e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                      814.000000                     861.000000
# mean                        49.771339                      32.659466
# std                         44.556308                      25.581758
# min                          0.000000                       0.000000
# 25%                          8.897500                       6.770000
# 50%                         35.885000                      28.820000
# 75%                         86.557500                      57.510000
# max                        137.870000                      71.240000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                           826.000000                  126.000000
# mean                             21.013535                    2.378095
# std                              19.924013                    1.967432
# min                               0.000000                    0.240000
# 25%                               3.230000                    1.197500
# 50%                              13.435000                    1.460000
# 75%                              39.482500                    3.225000
# max                              59.830000                    8.700000
#
#        new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# count                             891.000000                    8.910000e+02
# mean                             3025.470258                    1.331066e+06
# std                              1863.629852                    1.408930e+06
# min                                43.000000                    1.182300e+04
# 25%                              1313.000000                    2.629695e+05
# 50%                              3146.000000                    7.685190e+05
# 75%                              4663.500000                    2.043877e+06
# max                              7204.000000                    6.785334e+06
#
#        new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# count                                  891.000000       1559.000000
# mean                                     0.159570         67.103740
# std                                      0.112613         14.851369
# min                                      0.004000         10.190000
# 25%                                      0.067500         61.570000
# 50%                                      0.146000         68.980000
# 75%                                      0.240000         72.690000
# max                                      0.487000        100.000000
#
#          population  population_density   median_age  aged_65_older  \
# count  1.560000e+03         1560.000000  1560.000000    1560.000000
# mean   8.463423e+08          301.197067    28.738718       5.660872
# std    5.585852e+08          152.363787     0.550061       0.335037
# min    2.763618e+08          145.725000    28.200000       5.319000
# 25%    2.763618e+08          145.725000    28.200000       5.319000
# 50%    1.393409e+09          450.419000    28.200000       5.989000
# 75%    1.393409e+09          450.419000    29.300000       5.989000
# max    1.393409e+09          450.419000    29.300000       5.989000
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count    1560.000000     1560.000000      1560.000000            1560.000000
# mean        3.237203     8758.867256        13.608974             311.950626
# std         0.180520     2381.297365         7.750854              30.295338
# min         3.053000     6426.674000         5.700000             282.280000
# 25%         3.053000     6426.674000         5.700000             282.280000
# 50%         3.414000     6426.674000        21.200000             282.280000
# 75%         3.414000    11188.744000        21.200000             342.864000
# max         3.414000    11188.744000        21.200000             342.864000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count          1560.000000     1560.000000   1560.000000
# mean              8.396744        2.340769     47.780769
# std               2.035224        0.450050     27.753058
# min               6.320000        1.900000     20.600000
# 25%               6.320000        1.900000     20.600000
# 50%              10.390000        1.900000     20.600000
# 75%              10.390000        2.800000     76.100000
# max              10.390000        2.800000     76.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count             1560.000000                 1560.000000      1560.000000
# mean                61.829267                    0.779769        70.668872
# std                  2.327256                    0.255028         1.030113
# min                 59.550000                    0.530000        69.660000
# 25%                 59.550000                    0.530000        69.660000
# 50%                 59.550000                    0.530000        69.660000
# 75%                 64.204000                    1.040000        71.720000
# max                 64.204000                    1.040000        71.720000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count              1560.000000                                   0.0
# mean                  0.680751                                   NaN
# std                   0.036504                                   NaN
# min                   0.645000                                   NaN
# 25%                   0.645000                                   NaN
# 50%                   0.645000                                   NaN
# 75%                   0.718000                                   NaN
# max                   0.718000                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# count                          0.0               0.0
# mean                           NaN               NaN
# std                            NaN               NaN
# min                            NaN               NaN
# 25%                            NaN               NaN
# 50%                            NaN               NaN
# 75%                            NaN               NaN
# max                            NaN               NaN
#
#        excess_mortality_cumulative_per_million
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN

# %%
covid_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1560 entries, 73296 to 74855
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    1560 non-null   object
#  1   continent                                   1560 non-null   object
#  2   location                                    1560 non-null   object
#  3   date                                        1560 non-null   object
#  4   total_cases                                 1560 non-null   float64
#  5   new_cases                                   1557 non-null   float64
#  6   new_cases_smoothed                          1545 non-null   float64
#  7   total_deaths                                1510 non-null   float64
#  8   new_deaths                                  1505 non-null   float64
#  9   new_deaths_smoothed                         1481 non-null   float64
#  10  total_cases_per_million                     1560 non-null   float64
#  11  new_cases_per_million                       1557 non-null   float64
#  12  new_cases_smoothed_per_million              1545 non-null   float64
#  13  total_deaths_per_million                    1510 non-null   float64
#  14  new_deaths_per_million                      1505 non-null   float64
#  15  new_deaths_smoothed_per_million             1481 non-null   float64
#  16  reproduction_rate                           1495 non-null   float64
#  17  icu_patients                                0 non-null      float64
#  18  icu_patients_per_million                    0 non-null      float64
#  19  hosp_patients                               0 non-null      float64
#  20  hosp_patients_per_million                   0 non-null      float64
#  21  weekly_icu_admissions                       0 non-null      float64
#  22  weekly_icu_admissions_per_million           0 non-null      float64
#  23  weekly_hosp_admissions                      0 non-null      float64
#  24  weekly_hosp_admissions_per_million          0 non-null      float64
#  25  total_tests                                 1105 non-null   float64
#  26  new_tests                                   1090 non-null   float64
#  27  total_tests_per_thousand                    1105 non-null   float64
#  28  new_tests_per_thousand                      1090 non-null   float64
#  29  new_tests_smoothed                          1111 non-null   float64
#  30  new_tests_smoothed_per_thousand             1111 non-null   float64
#  31  positive_rate                               1110 non-null   float64
#  32  tests_per_case                              1110 non-null   float64
#  33  tests_units                                 1125 non-null   object
#  34  total_vaccinations                          814 non-null    float64
#  35  people_vaccinated                           861 non-null    float64
#  36  people_fully_vaccinated                     826 non-null    float64
#  37  total_boosters                              126 non-null    float64
#  38  new_vaccinations                            784 non-null    float64
#  39  new_vaccinations_smoothed                   891 non-null    float64
#  40  total_vaccinations_per_hundred              814 non-null    float64
#  41  people_vaccinated_per_hundred               861 non-null    float64
#  42  people_fully_vaccinated_per_hundred         826 non-null    float64
#  43  total_boosters_per_hundred                  126 non-null    float64
#  44  new_vaccinations_smoothed_per_million       891 non-null    float64
#  45  new_people_vaccinated_smoothed              891 non-null    float64
#  46  new_people_vaccinated_smoothed_per_hundred  891 non-null    float64
#  47  stringency_index                            1559 non-null   float64
#  48  population                                  1560 non-null   float64
#  49  population_density                          1560 non-null   float64
#  50  median_age                                  1560 non-null   float64
#  51  aged_65_older                               1560 non-null   float64
#  52  aged_70_older                               1560 non-null   float64
#  53  gdp_per_capita                              1560 non-null   float64
#  54  extreme_poverty                             1560 non-null   float64
#  55  cardiovasc_death_rate                       1560 non-null   float64
#  56  diabetes_prevalence                         1560 non-null   float64
#  57  female_smokers                              1560 non-null   float64
#  58  male_smokers                                1560 non-null   float64
#  59  handwashing_facilities                      1560 non-null   float64
#  60  hospital_beds_per_thousand                  1560 non-null   float64
#  61  life_expectancy                             1560 non-null   float64
#  62  human_development_index                     1560 non-null   float64
#  63  excess_mortality_cumulative_absolute        0 non-null      float64
#  64  excess_mortality_cumulative                 0 non-null      float64
#  65  excess_mortality                            0 non-null      float64
#  66  excess_mortality_cumulative_per_million     0 non-null      float64
# dtypes: float64(62), object(5)
# memory usage: 828.8+ KB

# %%
covid_df1['total_cases'].mean()
# Out:
# 10057964.960897436

# %%
covid_df1.shape
# Out:
# (1560, 67)

# %%
covid_df1['location'].value_counts()
# Out:
# India        796
# Indonesia    764
# Name: location, dtype: int64

# %% [markdown]
# ## Data Aggregation

# %%
# Create dataframe
data = {'Company':['GOJEK','GOJEK','TOKO','TOKO','FB','FB'],
       'Person':['Ayub','Amri','Calvin','Addie','Becca','Sara'],
       'Sales':[200,1200,340,124,243,350],
       'Margin':[40,40,34,100,56,60]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company  Person  Sales  Margin
# 0   GOJEK    Ayub    200      40
# 1   GOJEK    Amri   1200      40
# 2    TOKO  Calvin    340      34
# 3    TOKO   Addie    124     100
# 4      FB   Becca    243      56
# 5      FB    Sara    350      60

# %%
df.describe()
# Out:
#              Sales      Margin
# count     6.000000    6.000000
# mean    409.500000   55.000000
# std     396.581265   24.256958
# min     124.000000   34.000000
# 25%     210.750000   40.000000
# 50%     291.500000   48.000000
# 75%     347.500000   59.000000
# max    1200.000000  100.000000

# %% [markdown]
# **Now you can use the .groupby() method to group rows together based off of a column name**
#
#
# For instance let's group based off of Company. This will create a *DataFrameGroupBy* object:

# %%
df.groupby('Company')
#select company from df group by company

# %%
# You can save this object as a new variable:
by_comp = df.groupby("Company")

# %%
# And then call aggregate methods off the object:
by_comp.mean()
# Out:
#          Sales  Margin
# Company
# FB       296.5    58.0
# GOJEK    700.0    40.0
# TOKO     232.0    67.0

# %%
# In one step:
df.groupby('Company').mean()
# Out:
#          Sales  Margin
# Company
# FB       296.5    58.0
# GOJEK    700.0    40.0
# TOKO     232.0    67.0

# %% [markdown]
# **More examples of aggregate methods in pandas:**

# %%
by_comp.std()
# Out:
#               Sales     Margin
# Company
# FB        75.660426   2.828427
# GOJEK    707.106781   0.000000
# TOKO     152.735065  46.669048

# %%
by_comp.min()
# Out:
#         Person  Sales  Margin
# Company
# FB       Becca    243      56
# GOJEK     Amri    200      40
# TOKO     Addie    124      34

# %%
by_comp.max()
# Out:
#          Person  Sales  Margin
# Company
# FB         Sara    350      60
# GOJEK      Ayub   1200      40
# TOKO     Calvin    340     100

# %%
by_comp.count()
# Out:
#          Person  Sales  Margin
# Company
# FB            2      2       2
# GOJEK         2      2       2
# TOKO          2      2       2

# %%
by_comp.describe()
# Out:
#         Sales                                                          Margin  \
#         count   mean         std    min     25%    50%     75%     max  count
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25   350.0    2.0
# GOJEK     2.0  700.0  707.106781  200.0  450.00  700.0  950.00  1200.0    2.0
# TOKO      2.0  232.0  152.735065  124.0  178.00  232.0  286.00   340.0    2.0
#
#
#          mean        std   min   25%   50%   75%    max
# Company
# FB       58.0   2.828427  56.0  57.0  58.0  59.0   60.0
# GOJEK    40.0   0.000000  40.0  40.0  40.0  40.0   40.0
# TOKO     67.0  46.669048  34.0  50.5  67.0  83.5  100.0

# %%
df.groupby('Company')['Sales'].aggregate(['mean','sum'])
# Out:
#           mean   sum
# Company
# FB       296.5   593
# GOJEK    700.0  1400
# TOKO     232.0   464

# %%
by_comp.describe().transpose()
# Out:
# Company               FB        GOJEK        TOKO
# Sales  count    2.000000     2.000000    2.000000
#        mean   296.500000   700.000000  232.000000
#        std     75.660426   707.106781  152.735065
#        min    243.000000   200.000000  124.000000
#        25%    269.750000   450.000000  178.000000
#        50%    296.500000   700.000000  232.000000
#        75%    323.250000   950.000000  286.000000
#        max    350.000000  1200.000000  340.000000
# Margin count    2.000000     2.000000    2.000000
#        mean    58.000000    40.000000   67.000000
#        std      2.828427     0.000000   46.669048
#        min     56.000000    40.000000   34.000000
#        25%     57.000000    40.000000   50.500000
#        50%     58.000000    40.000000   67.000000
#        75%     59.000000    40.000000   83.500000
#        max     60.000000    40.000000  100.000000

# %%
by_comp.describe().transpose()['GOJEK']
# Out:
# Sales   count       2.000000
#         mean      700.000000
#         std       707.106781
#         min       200.000000
#         25%       450.000000
#         50%       700.000000
#         75%       950.000000
#         max      1200.000000
# Margin  count       2.000000
#         mean       40.000000
#         std         0.000000
#         min        40.000000
#         25%        40.000000
#         50%        40.000000
#         75%        40.000000
#         max        40.000000
# Name: GOJEK, dtype: float64

# %%
# Let's try some aggregagation on our COVID Data:
covid_df.groupby(['continent','location'])['new_cases'].aggregate(['count','mean','median']).sort_values('location')
# Out:
#                                                 count          mean   median
# continent     location
# Asia          Afghanistan                         769    231.345904     78.0
# Europe        Albania                             757    361.840159    164.0
# Africa        Algeria                             770    345.057143    224.0
# Europe        Andorra                             759     52.732543     11.0
# Africa        Angola                              746    132.967828     66.0
# North America Anguilla                            738      3.658537      0.0
#               Antigua and Barbuda                 751      9.980027      0.0
# South America Argentina                           763  11852.028834   6935.0
# Asia          Armenia                             765    552.393464    320.0
# North America Aruba                               753     45.220452     17.0
# Oceania       Australia                           798   6017.348371     37.0
# Europe        Austria                             770   5064.493506   1435.5
# Asia          Azerbaijan                          765   1035.381699    421.0
# North America Bahamas                             749     44.540721      7.0
# Asia          Bahrain                             771    722.130999    339.0
#               Bangladesh                          758   2574.974934   1534.5
# North America Barbados                            749     80.320427      6.0
# Europe        Belarus                             767   1259.001304   1057.0
#               Belgium                             791   4907.108723   1630.0
# North America Belize                              743     77.123822     12.0
# Africa        Benin                               749     36.263017      0.0
# North America Bermuda                             743     16.909825      0.0
# Asia          Bhutan                              760     42.009211      1.0
# South America Bolivia                             755   1195.360265    661.0
# North America Bonaire Sint Eustatius and Saba     733     12.075034      0.0
# Europe        Bosnia and Herzegovina              761    493.738502    227.0
# Africa        Botswana                            731    417.956224      0.0
# South America Brazil                              767  38996.447197  31698.0
# North America British Virgin Islands              738      8.340108      0.0
# Asia          Brunei                              756    180.412698      0.0
# Europe        Bulgaria                            758   1506.410290    666.0
# Africa        Burkina Faso                        756     27.589947      6.0
#               Burundi                             735     52.500680      3.0
# Asia          Cambodia                            799    169.939925      7.0
# Africa        Cameroon                            760    157.294737      0.0
# North America Canada                              803   4370.393524   2476.0
# Africa        Cape Verde                          746     75.014745     40.0
# North America Cayman Islands                      753     27.365206      0.0
# Africa        Central African Republic            751     19.505992      0.0
#               Chad                                747      9.835341      2.0
# South America Chile                               772   4520.612694   2131.0
# Asia          China                               801    339.310861     43.0
# South America Colombia                            760   8008.201316   6047.0
# Africa        Comoros                             705     11.479433      1.0
#               Congo                               751     32.051931      0.0
# Oceania       Cook Islands                        319      7.918495      0.0
# North America Costa Rica                          757   1108.808454    487.0
# Africa        Cote d'Ivoire                       754    108.494695     50.0
# Europe        Croatia                             770   1432.242857    475.0
# North America Cuba                                754   1449.822281    511.5
#               Curacao                             749     54.300401     10.0
# Europe        Cyprus                              756    587.531746    169.5
#               Czechia                             763   5035.619921   1529.0
# Africa        Democratic Republic of Congo        755    114.898013     46.0
# Europe        Denmark                             767   4003.874837    677.0
# Africa        Djibouti                            748     20.842246      3.0
# North America Dominica                            743     16.049798      0.0
#               Dominican Republic                  765    755.828758    528.0
# South America Ecuador                             760   1149.728947    701.5
# Africa        Egypt                               781    651.955186    608.0
# North America El Salvador                         745    216.995973     96.0
# Africa        Equatorial Guinea                   751     21.304927      0.0
#               Eritrea                             745     13.057718      2.0
# Europe        Estonia                             768    728.037760    299.5
# Africa        Eswatini                            752     92.901596     22.5
#               Ethiopia                            753    623.961487    440.0
# Europe        Faeroe Islands                      762     45.482940      0.0
# South America Falkland Islands                    729      0.172840      0.0
# Oceania       Fiji                                747     86.244980      0.0
# Europe        Finland                             797   1130.910916    247.0
#               France                              792  33468.412879  10585.5
# Oceania       French Polynesia                    752     96.269947      0.0
# Africa        Gabon                               752     63.281915      0.0
#               Gambia                              748     16.161765      0.0
# Asia          Georgia                             769   2144.902471    888.0
# Europe        Germany                             797  27235.112923   7334.0
# Africa        Ghana                               752    214.057181     69.0
# Europe        Gibraltar                           758     22.602902      5.0
#               Greece                              769   4026.183355   1464.0
# North America Greenland                           749     15.983979      0.0
#               Grenada                             743     18.897712      0.0
# Oceania       Guam                                  0           NaN      NaN
# North America Guatemala                           752   1105.251330    717.5
# Europe        Guernsey                              0           NaN      NaN
# Africa        Guinea                              753     48.418327     27.0
#               Guinea-Bissau                       741     11.000000      0.0
# South America Guyana                              753     84.047809     42.0
# North America Haiti                               746     40.974531     13.0
#               Honduras                            754    558.542440    441.5
# Asia          Hong Kong                           801   1466.397004      7.0
# Europe        Hungary                             759   2442.948617    576.0
#               Iceland                             763    238.310616      8.0
# Asia          India                               796  54057.586683  26336.5
#               Indonesia                           761   7905.056505   4071.0
#               Iran                                776   9241.192010   6374.5
#               Iraq                                771   3009.761349   2383.0
# Europe        Ireland                             762   1945.947507    533.0
#               Isle of Man                         746     38.726542      1.0
# Asia          Israel                              771   5134.529183   1159.0
# Europe        Italy                               794  18737.143577   5742.0
# North America Jamaica                             755    170.687417     73.0
# Asia          Japan                               803   8381.882939   1229.0
# Europe        Jersey                                0           NaN      NaN
# Asia          Jordan                              762   2223.524934    977.0
#               Kazakhstan                          752   1932.571809    941.5
# Africa        Kenya                               753    429.572377    241.0
# Oceania       Kiribati                            321      9.566978      0.0
# Europe        Kosovo                              752    302.631649     48.0
# Asia          Kuwait                              770    817.564935    595.5
#               Kyrgyzstan                          748    268.673797    114.5
#               Laos                                742    248.784367      1.0
# Europe        Latvia                              764   1050.899215    310.0
# Asia          Lebanon                             774   1412.489664    803.5
# Africa        Lesotho                             692     47.557803      0.0
#               Liberia                             747     10.074967      0.0
#               Libya                               742    676.196765    536.0
# Europe        Liechtenstein                       760     21.622368      3.0
#               Lithuania                           766   1346.917755    605.5
#               Luxembourg                          765    288.546405     80.0
# Asia          Macao                               803      0.100872      0.0
# Africa        Madagascar                          745     85.982550      3.0
#               Malawi                              733    116.867667     18.0
# Asia          Malaysia                            801   5313.943820   2340.0
#               Maldives                            758    234.386544    103.0
# Africa        Mali                                741     41.168691     17.0
# Europe        Malta                               758    108.401055     52.5
# Oceania       Marshall Islands                    523      0.015296      0.0
# Africa        Mauritania                          752     78.065160     35.0
#               Mauritius                           738    285.210027      0.0
# North America Mexico                              767   7388.423729   4960.0
# Oceania       Micronesia (country)                439      0.002278      0.0
# Europe        Moldova                             758    678.393140    418.0
#               Monaco                              765     14.227451      3.0
# Asia          Mongolia                            756   1216.328042     47.5
# Europe        Montenegro                          749    311.568758    212.0
# North America Montserrat                          748      0.233957      0.0
# Africa        Morocco                             764   1522.985602    507.5
#               Mozambique                          743    303.207268     74.0
# Asia          Myanmar                             739    828.046008    281.0
# Africa        Namibia                             752    209.792553     91.0
# Oceania       Nauru                                 0           NaN      NaN
# Asia          Nepal                               800   1223.135000    436.0
# Europe        Netherlands                         768  10436.162760   4320.5
# Oceania       New Caledonia                       746     81.000000      0.0
#               New Zealand                         763    940.570118      4.0
# North America Nicaragua                           747     24.677376      0.0
# Africa        Niger                               745     11.832215      4.0
#               Nigeria                             767    333.074316    166.0
# Oceania       Niue                                  0           NaN      NaN
# Europe        North Macedonia                     769    398.843953    242.0
# Asia          Northern Cyprus                       0           NaN      NaN
# Oceania       Northern Mariana Islands              0           NaN      NaN
# Europe        Norway                              769   1833.616385    363.0
# Asia          Oman                                771    503.891051    154.0
#               Pakistan                            770   1981.525974   1430.5
# Oceania       Palau                               226     17.884956      0.0
# Asia          Palestine                           761    862.400788    408.0
# North America Panama                              756   1012.350529    575.0
# Oceania       Papua New Guinea                    745     58.241611      0.0
# South America Paraguay                            755    858.745695    427.0
#               Peru                                760   4669.364474   2184.5
# Asia          Philippines                         794   4634.905542   2069.0
# Oceania       Pitcairn                              0           NaN      NaN
# Europe        Poland                              762   7834.795276   2722.0
#               Portugal                            763   4731.332896    902.0
# North America Puerto Rico                           0           NaN      NaN
# Asia          Qatar                               766    472.593995    227.0
# Europe        Romania                             769   3720.970091   1591.0
#               Russia                              795  22202.576101  15704.0
# Africa        Rwanda                              752    172.517287     47.5
#               Saint Helena                        575      0.006957      0.0
# North America Saint Kitts and Nevis               741      7.488529      0.0
#               Saint Lucia                         752     30.538564      4.0
#               Saint Pierre and Miquelon           726      3.082645      0.0
#               Saint Vincent and the Grenadines    751     13.154461      0.0
# Oceania       Samoa                               503      5.212724      0.0
# Europe        San Marino                          766     20.032637      2.0
# Africa        Sao Tome and Principe               728      8.174451      1.0
# Asia          Saudi Arabia                        764    983.219895    438.5
# Africa        Senegal                             764    112.460733     51.5
# Europe        Serbia                              760   2608.148684   1425.5
# Africa        Seychelles                          748     54.640374      0.0
#               Sierra Leone                        735     10.442177      3.0
# Asia          Singapore                           802   1383.720698     53.0
# North America Sint Maarten (Dutch part)             0           NaN      NaN
# Europe        Slovakia                            760   3239.868421   1042.5
#               Slovenia                            761   1280.806833    520.0
# Oceania       Solomon Islands                     535     21.444860      0.0
# Africa        Somalia                             750     35.213333      0.0
#               South Africa                        759   4880.590250   2312.0
# Asia          South Korea                         803  17767.621420    520.0
# Africa        South Sudan                         730     23.700000      4.5
# Europe        Spain                               787  14785.781449   4091.0
# Asia          Sri Lanka                           799    828.664581    517.0
# Africa        Sudan                               751     82.528628      6.0
# South America Suriname                            752    105.367021     38.0
# Europe        Sweden                              790   3149.179747    342.0
#               Switzerland                         767   4572.762712    530.0
# Asia          Syria                               744     74.889785     55.0
#               Taiwan                              801     30.699126      4.0
#               Tajikistan                          704     25.264205      1.5
# Africa        Tanzania                            750     45.086667      0.0
# Asia          Thailand                            802   4685.273067    194.0
#               Timor                               743     30.736205      0.0
# Africa        Togo                                760     48.611842     15.0
# Oceania       Tokelau                               0           NaN      NaN
#               Tonga                               158     45.784810      0.0
# North America Trinidad and Tobago                 752    184.565160     76.0
# Africa        Tunisia                             756   1370.216931    656.5
# Asia          Turkey                              754  18679.248011  10032.5
#               Turkmenistan                          0           NaN      NaN
# North America Turks and Caicos Islands            737      8.020353      0.0
# Oceania       Tuvalu                                0           NaN      NaN
# Africa        Uganda                              743    220.799462     67.0
# Europe        Ukraine                             763   6606.183486   3432.0
# Asia          United Arab Emirates                797   1119.786700    971.0
# Europe        United Kingdom                      792  25995.275253  13484.0
# North America United States                       803  99849.673724  55080.0
#               United States Virgin Islands          0           NaN      NaN
# South America Uruguay                             752   1183.724734    196.0
# Asia          Uzbekistan                          751    316.761651    241.0
# Oceania       Vanuatu                             511      8.671233      0.0
# Europe        Vatican                             760      0.038158      0.0
# South America Venezuela                           752    692.692819    532.5
# Asia          Vietnam                             803  12287.727273     12.0
# Oceania       Wallis and Futuna                   533      0.851782      0.0
# Asia          Yemen                               724     16.310773      5.0
# Africa        Zambia                              748    423.943850    102.0
#               Zimbabwe                            745    331.030872     62.0

# %%
df.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a4fc9c00d097> in <module>()
# ----> 1 df.groupby()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624
#    7625         if level is None and by is None:
# -> 7626             raise TypeError("You have to supply one of 'by' and 'level'")
#    7627         axis = self._get_axis_number(axis)
#    7628
#
# TypeError: You have to supply one of 'by' and 'level'

# %% [markdown]
# ## Operations on Pandas Columns
# * Addition, Subtraction, etc.
# * sort_values(), sort_index()
# * Dropping columns
# * Applying functions to Pandas Dataframes (Map and Apply)

# %% [markdown]
# ### Column Operations

# %%
temp_df = covid_df1 [['location',	'date', 'new_cases']].tail(10)
temp_df
# Out:
#         location        date  new_cases
# 74846  Indonesia  2022-03-26        0.0
# 74847  Indonesia  2022-03-27     9046.0
# 74848  Indonesia  2022-03-28     5875.0
# 74849  Indonesia  2022-03-29     3895.0
# 74850  Indonesia  2022-03-30     3840.0
# 74851  Indonesia  2022-03-31     3332.0
# 74852  Indonesia  2022-04-01     2930.0
# 74853  Indonesia  2022-04-02        NaN
# 74854  Indonesia  2022-04-03        NaN
# 74855  Indonesia  2022-04-04        NaN

# %%
temp_df['new_cases_added'] = temp_df['new_cases'] + temp_df['new_cases']
temp_df
# Out:
#         location        date  new_cases  new_cases_added
# 74846  Indonesia  2022-03-26        0.0              0.0
# 74847  Indonesia  2022-03-27     9046.0          18092.0
# 74848  Indonesia  2022-03-28     5875.0          11750.0
# 74849  Indonesia  2022-03-29     3895.0           7790.0
# 74850  Indonesia  2022-03-30     3840.0           7680.0
# 74851  Indonesia  2022-03-31     3332.0           6664.0
# 74852  Indonesia  2022-04-01     2930.0           5860.0
# 74853  Indonesia  2022-04-02        NaN              NaN
# 74854  Indonesia  2022-04-03        NaN              NaN
# 74855  Indonesia  2022-04-04        NaN              NaN

# %%
temp_df['new_cases_twice'] = temp_df['new_cases'] *2

# %%
temp_df.sort_values(by = ['new_cases','date'],ascending=[False,True], inplace=True)

# %%
temp_df
# Out:
#         location        date  new_cases  new_cases_added  new_cases_twice
# 74847  Indonesia  2022-03-27     9046.0          18092.0          18092.0
# 74848  Indonesia  2022-03-28     5875.0          11750.0          11750.0
# 74849  Indonesia  2022-03-29     3895.0           7790.0           7790.0
# 74850  Indonesia  2022-03-30     3840.0           7680.0           7680.0
# 74851  Indonesia  2022-03-31     3332.0           6664.0           6664.0
# 74852  Indonesia  2022-04-01     2930.0           5860.0           5860.0
# 74846  Indonesia  2022-03-26        0.0              0.0              0.0
# 74853  Indonesia  2022-04-02        NaN              NaN              NaN
# 74854  Indonesia  2022-04-03        NaN              NaN              NaN
# 74855  Indonesia  2022-04-04        NaN              NaN              NaN

# %%
temp_df.sort_index(inplace=True)
temp_df
# Out:
#         location        date  new_cases  new_cases_added  new_cases_twice
# 74846  Indonesia  2022-03-26        0.0              0.0              0.0
# 74847  Indonesia  2022-03-27     9046.0          18092.0          18092.0
# 74848  Indonesia  2022-03-28     5875.0          11750.0          11750.0
# 74849  Indonesia  2022-03-29     3895.0           7790.0           7790.0
# 74850  Indonesia  2022-03-30     3840.0           7680.0           7680.0
# 74851  Indonesia  2022-03-31     3332.0           6664.0           6664.0
# 74852  Indonesia  2022-04-01     2930.0           5860.0           5860.0
# 74853  Indonesia  2022-04-02        NaN              NaN              NaN
# 74854  Indonesia  2022-04-03        NaN              NaN              NaN
# 74855  Indonesia  2022-04-04        NaN              NaN              NaN

# %%
temp_df.drop(['new_cases_added','new_cases_twice'],axis = 1)
# Out:
#         location        date  new_cases
# 74846  Indonesia  2022-03-26        0.0
# 74847  Indonesia  2022-03-27     9046.0
# 74848  Indonesia  2022-03-28     5875.0
# 74849  Indonesia  2022-03-29     3895.0
# 74850  Indonesia  2022-03-30     3840.0
# 74851  Indonesia  2022-03-31     3332.0
# 74852  Indonesia  2022-04-01     2930.0
# 74853  Indonesia  2022-04-02        NaN
# 74854  Indonesia  2022-04-03        NaN
# 74855  Indonesia  2022-04-04        NaN

# %%
temp_df
# Out:
#         location        date  new_cases  new_cases_added  new_cases_twice
# 74846  Indonesia  2022-03-26        0.0              0.0              0.0
# 74847  Indonesia  2022-03-27     9046.0          18092.0          18092.0
# 74848  Indonesia  2022-03-28     5875.0          11750.0          11750.0
# 74849  Indonesia  2022-03-29     3895.0           7790.0           7790.0
# 74850  Indonesia  2022-03-30     3840.0           7680.0           7680.0
# 74851  Indonesia  2022-03-31     3332.0           6664.0           6664.0
# 74852  Indonesia  2022-04-01     2930.0           5860.0           5860.0
# 74853  Indonesia  2022-04-02        NaN              NaN              NaN
# 74854  Indonesia  2022-04-03        NaN              NaN              NaN
# 74855  Indonesia  2022-04-04        NaN              NaN              NaN

# %%
temp_df.drop(columns = ['new_cases_added','new_cases_twice'],inplace = True)

# %% [markdown]
# ### Applying functions to Pandas dataframes
# [Reference Link for Map and Apply](https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff)

# %%
temp_df

# %%
# In-built Python method
temp_df['sqrt_new_cases'] = temp_df['new_cases'].apply(np.sqrt)
temp_df

# %% [markdown]
# Create a column as 'new_cases_category' which shows:
# * <=40 Cases             -- 'Low'
# * 40k+ to 50k Cases      -- 'Medium'
# * Greater than 50k Cases -- 'High'

# %%
# UDF - User defined function
def category_fn (number_of_cases):
  if number_of_cases<=40000: cat = 'Low'
  elif number_of_cases>50000: cat = 'High'
  else: cat = 'Medium'
  return cat

# %%
category_fn (55000)

# %%
temp_df['new_cases_category'] = temp_df['new_cases'].apply(category_fn)
temp_df

# %%
temp_df['new_cases_category1'] = temp_df['new_cases'].map(category_fn)
temp_df

# %% [markdown]
# #### Comparing map, applymap and apply: **Context Matters**
#
# [Reference Link](https://stackoverflow.com/questions/19798153/difference-between-map-applymap-and-apply-methods-in-pandas)
#
# **First major difference: DEFINITION**
#
# * `map` is defined on Series ONLY
# * `applymap` is defined on DataFrames ONLY
# * `apply` is defined on BOTH
#
# **Second major difference: INPUT ARGUMENT**
# * `map` accepts dicts, Series, or callable
# * `applymap` and apply accept callables only
#
# **Third major difference: BEHAVIOR**
#
# * `map` is elementwise for Series
# * `applymap` is elementwise for DataFrames
# * `apply` also works elementwise but is suited to more complex operations and aggregation. The behaviour and return value depends on the function.
#
# **Fourth major difference (the most important one): USE CASE**
#
# * `map` is meant for mapping values from one domain to another, so is optimised for performance (e.g., df['A'].map({1:'a', 2:'b', 3:'c'}))
# * `applymap` is good for elementwise transformations across multiple rows/columns (e.g., df[['A', 'B', 'C']].applymap(str.strip))
# * `apply` is for applying any function that cannot be vectorised (e.g., df['sentences'].apply(nltk.sent_tokenize))
#
# &nbsp;
#
# **Summarizing:**
# <img src="https://i.stack.imgur.com/IZys3.png">
#
# > **Footnotes:**
# 1. `map` when passed a dictionary/Series will map elements based on the keys in that dictionary/Series. Missing values will be recorded as NaN in the output.
# 2. `applymap` in more recent versions has been optimised for some operations. You will find `applymap` slightly faster than apply in some cases. My suggestion is to test them both and use whatever works better.
# 3. `map` is optimised for elementwise mappings and transformation. Operations that involve dictionaries or Series will enable pandas to use faster code paths for better performance.
# 4. `Series.apply` returns a scalar for aggregating operations, Series otherwise. Similarly for `DataFrame.apply`. Note that `apply` also has fastpaths when called with certain NumPy functions such as `mean`, `sum`, etc.

# %%
df['married_cat1']=df.apply(lambda x: if(x['married_cat'].isna(): if x['age']>30: 'married'  else: 'single' else: x['married_cat'],axis=1)

# %% [markdown]
# ## Merging, Joining, and Concatenating (Optional)
#
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating. In this section we will discuss these 3 methods with examples.

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ### Concatenation
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use pd.concat and pass in a list of DataFrames to concatenate together:

# %%
# Similar to Union of 2 or more tables in SQL
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df2.reset_index()
# Out:
#    index   A   B   C   D
# 0      4  A4  B4  C4  D4
# 1      5  A5  B5  C5  D5
# 2      6  A6  B6  C6  D6
# 3      7  A7  B7  C7  D7

# %%
pd.concat([df1,df2.reset_index(drop=True),df3.reset_index(drop=True)],axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  A0  B0  C0  D0  A4  B4  C4  D4   A8   B8   C8   D8
# 1  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11

# %% [markdown]
# ### Merging
#
# The **merge** function allows you to merge DataFrames together using a similar logic as joining SQL Tables together.

# %%
df1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-0b6a759156bb> in <module>()
# ----> 1 left
#
# NameError: name 'left' is not defined

# %%
right

# %%
pd.merge(df1,df2,how='inner',on='key')

# %% [markdown]
# More complicated example:

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left, right, on=['key1', 'key2'])

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])

# %%
pd.merge(left, right, how='inner', left_on = 'key1', right_on = 'key2')

# %% [markdown]
# ### Joining
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)

# %%
left.join(right, how='outer')
